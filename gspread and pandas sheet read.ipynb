# %%
# !pip install gspread

# %%
import pandas as pd
import gspread as gp

# %%
gc= gp.service_account(filename='D:\\Python learning\\DATA SCIENCE & ML\\blissful-column-378812-0371f65aef6b.json')

# %%
gc

# %%
sheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1UGBdNri8ThEuuP2wN5Jf8TDCA_R6QBeEj847tos3-Go/edit?usp=sharing')

# %%
sheet
# Out:
# <Spreadsheet 'Screen Time Data' id:1UGBdNri8ThEuuP2wN5Jf8TDCA_R6QBeEj847tos3-Go>

# %%
ws = sheet.worksheet('Screen Time Data')

# %%
ws
# Out:
# <Worksheet 'Screen Time Data' id:968542157>

# %%
df = pd.DataFrame(ws.get_all_records())
df
# Out:
#     index      Date   Week Day  Total Screen Time  Social Networking  \
# 0       0  04/17/19  Wednesday                187                 89
# 1       1  04/18/19   Thursday                123                 78
# 2       2  04/19/19     Friday                112                 52
# 3       3  04/20/19   Saturday                101                 69
# 4       4  04/21/19     Sunday                 56                 35
# 5       5  04/22/19     Monday                189                 68
# 6       6  04/23/19    Tuesday                158                 56
# 7       7  04/24/19  Wednesday                135                 98
# 8       8  04/25/19   Thursday                 52                 25
# 9       9  04/26/19     Friday                198                 76
# 10     10  04/27/19   Saturday                116                 75
# 11     11  04/28/19     Sunday                 85                 42
# 12     12  04/29/19     Monday                109                 46
# ...

# %%
ws2 = sheet.worksheet('name1')
ws2
# Out:
# <Worksheet 'name1' id:329605111>

# %%
df2 = pd.DataFrame(ws2.get_all_records())
df2
# Out:
#         2
# 0      fg  414
# 1    fdgd  411
# 2      df   14
# 3     age    2
# 4  yeasin   25
# 5   noman   26
# 6   sadia   24
