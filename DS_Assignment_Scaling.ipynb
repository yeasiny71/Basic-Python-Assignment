# %%
import pandas as pd

# %%
df = pd.read_csv('supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
x = df.drop('Profit',axis = 1)
y = df[['Profit']]

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y.head()
# Out:
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
x1 = x.copy()
x2 = x.copy()
x3 = x.copy()
x4 = x.copy()
x5 = x.copy()
x6 = x.copy()
x7 = x.copy()
x8 = x.copy()

# %% [markdown]
# # MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m = MinMaxScaler()

# %%
x1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
x1[['Marketing Spend']] = m.fit_transform(x1[['Marketing Spend']])

# %%
x1[['Administration']] = m.fit_transform(x1[['Administration']])

# %%
x1[['Transport']] = m.fit_transform(x1[['Transport']])

# %%
x1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.651744   1.000000    Dhaka
# 1         0.983359        0.761972   0.940893      Ctg
# 2         0.927985        0.379579   0.864664  Rangpur
# 3         0.873136        0.512998   0.812235    Dhaka
# 4         0.859438        0.305328   0.776136  Rangpur

# %% [markdown]
# # MinMaxScaler using for loop.

# %%
x2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
for column in x2.columns:
    if pd.api.types.is_numeric_dtype(x2[column]):
        x2[column] = m.fit_transform(x2[[column]])
    else:
        continue
x2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.651744   1.000000    Dhaka
# 1         0.983359        0.761972   0.940893      Ctg
# 2         0.927985        0.379579   0.864664  Rangpur
# 3         0.873136        0.512998   0.812235    Dhaka
# 4         0.859438        0.305328   0.776136  Rangpur

# %% [markdown]
# # Standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
s = StandardScaler()

# %%
x3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
x3['Marketing Spend'] = s.fit_transform(x2[['Marketing Spend']])

# %%
x3['Administration'] = s.fit_transform(x3[['Administration']])

# %%
x3['Transport'] = s.fit_transform(x3[['Transport']])

# %%
x3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.897913        0.560753   2.165287    Dhaka
# 1         1.955860        1.082807   1.929843      Ctg
# 2         1.754364       -0.728257   1.626191  Rangpur
# 3         1.554784       -0.096365   1.417348    Dhaka
# 4         1.504937       -1.079919   1.273550  Rangpur

# %% [markdown]
# # Standard scaler using for loop

# %%
x4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
for column in x4.columns:
    if pd.api.types.is_numeric_dtype(x4[column]):
        x4[column] = s.fit_transform(x4[[column]])
    else:
        continue
x4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.897913        0.560753   2.165287    Dhaka
# 1         1.955860        1.082807   1.929843      Ctg
# 2         1.754364       -0.728257   1.626191  Rangpur
# 3         1.554784       -0.096365   1.417348    Dhaka
# 4         1.504937       -1.079919   1.273550  Rangpur

# %% [markdown]
# # Max absolute scaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
ms = MaxAbsScaler()

# %%
x5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
x5['Marketing Spend'] = ms.fit_transform(x5[['Marketing Spend']])

# %%
x5['Administration'] = ms.fit_transform(x5[['Administration']])

# %%
x5['Transport'] = ms.fit_transform(x5[['Transport']])

# %%
x5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.749527   1.000000    Dhaka
# 1         0.983359        0.828805   0.940893      Ctg
# 2         0.927985        0.553781   0.864664  Rangpur
# 3         0.873136        0.649738   0.812235    Dhaka
# 4         0.859438        0.500378   0.776136  Rangpur

# %% [markdown]
# # Max absolute scaler using for loop

# %%
x6.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
for column in x6.columns:
    if pd.api.types.is_numeric_dtype(x6[column]):
        x6[column] = ms.fit_transform(x4[[column]])
    else:
        continue
x6.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.445303        0.221993   1.000000    Dhaka
# 1         0.969971        0.428666   0.891264      Ctg
# 2         0.870043       -0.288305   0.751028  Rangpur
# 3         0.771065       -0.038149   0.654577    Dhaka
# 4         0.746344       -0.427523   0.588166  Rangpur

# %% [markdown]
# # Robust scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs = RobustScaler()

# %%
x7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
x7['Marketing Spend'] = rs.fit_transform(x7[['Marketing Spend']])

# %%
x7['Administration'] = rs.fit_transform(x7[['Administration']])

# %%
x7['Transport'] = rs.fit_transform(x7[['Transport']])

# %%
x7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.672530        0.345355   1.552016    Dhaka
# 1         1.452113        0.697565   1.383714      Ctg
# 2         1.303634       -0.524290   1.166654  Rangpur
# 3         1.156567       -0.097977   1.017368    Dhaka
# 4         1.119836       -0.761543   0.914576  Rangpur

# %% [markdown]
# # Robust scaler using for loop

# %%
x8.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
for col in x8.columns:
    if pd.api.types.is_numeric_dtype(x8[col]):
        x8[col] = rs.fit_transform(x8[[col]])
    else:
        continue
x8.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.672530        0.345355   1.552016    Dhaka
# 1         1.452113        0.697565   1.383714      Ctg
# 2         1.303634       -0.524290   1.166654  Rangpur
# 3         1.156567       -0.097977   1.017368    Dhaka
# 4         1.119836       -0.761543   0.914576  Rangpur
